# %% [markdown]
# # Petfinder Data
#
# This notebook opens then explores the dog_PetFinder_descriptions csv. This data is from the company/pet adoption agency Petfinder in 2019. The data has over 58,000 rows and 35 columns detailing primary breed, secondary breed, species, description, location data, and many more aspects of the adoption listings of each of these dogs. However, I am only interested in the primary and secondary breed of these pets as well as the species. This csv is from 2019 and will not change because none of the data was recorded outside of this year.

# %%
import pandas as pd
import random
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
petfinder_data=pd.read_csv('../data/dog_PetFinder_descriptions.csv')

# %%
petfinder_data.head()
# Out:
#          id org_id                                                url type.x  \
# 0  46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...    Dog
# 1  46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...    Dog
# 2  46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...    Dog
# 3  46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...    Dog
# 4  46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...    Dog
#
#   species                   breed_primary breed_secondary  breed_mixed  \
# 0     Dog  American Staffordshire Terrier     Mixed Breed         True
# 1     Dog                Pit Bull Terrier     Mixed Breed         True
# 2     Dog                        Shepherd             NaN        False
# 3     Dog             German Shepherd Dog             NaN        False
# 4     Dog                       Dachshund             NaN        False
#
# ...

# %%
petfinder_data.shape
# Out:
# (58180, 35)

# %%
petfinder_data['breed_primary'].value_counts()
# Out:
# Pit Bull Terrier                7890
# Labrador Retriever              7198
# Chihuahua                       3766
# Mixed Breed                     3242
# Terrier                         2641
#                                 ...
# Wirehaired Pointing Griffon        1
# Boykin Spaniel                     1
# Old English Sheepdog               1
# Belgian Shepherd / Laekenois       1
# Tosa Inu                           1
# Name: breed_primary, Length: 216, dtype: int64
