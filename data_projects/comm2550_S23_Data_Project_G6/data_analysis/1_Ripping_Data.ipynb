# %% [markdown]
# ### Ripping Data ###

# %% [markdown]
# This entire notebook is just figuring out how to rip the data form the NBA website. I am keeping it in the data analysis folder because there is a thought process behind which data I am ripping
#
# A) I am ripping directly from the NBA website so there is little to no false reporting
# B) I am using basic stats, and will focus on specifically the three main stats of basketball (PPG, RPG, APG), because there is too much data in basketball to use all of it properly. By shortening the selection field for data I can do a proper analysis.
# C) I avoid advanced metrics because there are large arguments surrounding their validity.
#
# I explain the uses for each bit of data in the ReadMe book under inside the Data folder.

# %%
tables= pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Regular_Season')

# %%
import pandas as pd

# %%
tables[6]
# Out:
#       #                   Player Team  GP   MPG   PPG   FGM   FGA    FG%  3PM  \
# 0     1              Joel Embiid  PHI  66  34.6  33.1  11.0  20.1  0.548  1.0
# 1     2              Luka Doncic  DAL  66  36.2  32.4  10.9  22.0  0.496  2.8
# 2     3           Damian Lillard  POR  58  36.3  32.2   9.6  20.7  0.463  4.2
# 3     4  Shai Gilgeous-Alexander  OKC  68  35.5  31.4  10.4  20.3  0.510  0.9
# 4     5    Giannis Antetokounmpo  MIL  63  32.1  31.1  11.2  20.3  0.553  0.7
# ..  ...                      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 95   96             Cole Anthony  ORL  60  25.9  13.0   4.6  10.2  0.454  1.3
# 96   97            Austin Reaves  LAL  64  28.8  13.0   4.0   7.7  0.529  1.3
# 97   98                Tre Jones  SAS  68  29.2  12.9   5.0  10.9  0.459  0.7
# 98   99        Jabari Smith, Jr.  HOU  79  31.0  12.8   4.6  11.3  0.408  1.5
# 99  100              K.J. Martin  HOU  82  28.0  12.7   5.0   8.8  0.569  0.8
#
# ...

# %%
tables2= pd.read_html('https://basketball.realgm.com/nba/stats/2023/Advanced_Stats/Qualified/points/All/desc/1/Regular_Season')

# %%
tables2[6]
# Out:
#       #                 Player Team    TS%   eFG%  Total S %  ORB%  DRB%  \
# 0     1            Joel Embiid  PHI  0.655  0.573      173.6   6.0  28.1
# 1     2           Nikola Jokic  DEN  0.701  0.660      183.6   8.6  31.2
# 2     3            Luka Doncic  DAL  0.609  0.560      158.0   2.7  25.4
# 3     4  Giannis Antetokounmpo  MIL  0.605  0.572      147.3   7.4  29.5
# 4     5           Jimmy Butler  MIA  0.647  0.560      173.9   7.6  13.5
# ..  ...                    ...  ...    ...    ...        ...   ...   ...
# 95   96        Cameron Johnson  BRK  0.617  0.579      171.6   3.1  14.3
# 96   97         T.J. McConnell  IND  0.590  0.568      183.7   3.3  13.8
# 97   98          Mikal Bridges  BRK  0.587  0.535      174.6   2.9  10.9
# 98   99            Ivica Zubac  LAC  0.661  0.634      133.2  12.4  26.5
# 99  100    Michael Porter, Jr.  DEN  0.621  0.602      170.1   4.2  17.2
#
#     TRB%  AST%  ...  STL%  BLK%  USG%   PPR  PPS   ORtg   DRtg  eDiff     FIC  \
# ...

# %%
tables3= pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Pre-All-Star_Game')

# %%
tables3[6]
# Out:
#       #                   Player Team  GP   MPG   PPG   FGM   FGA    FG%  3PM  \
# 0     1              Luka Doncic  DAL  50  36.5  33.3  11.2  22.2  0.505  2.7
# 1     2              Joel Embiid  PHI  45  34.9  33.1  11.0  20.5  0.537  1.1
# 2     3    Giannis Antetokounmpo  MIL  47  33.1  31.8  11.3  21.0  0.538  0.8
# 3     4           Damian Lillard  POR  46  36.2  31.4   9.5  20.2  0.467  4.2
# 4     5  Shai Gilgeous-Alexander  OKC  53  35.4  30.8  10.2  20.1  0.508  0.9
# ..  ...                      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 95   96        Bogdan Bogdanovic  ATL  34  29.8  14.6   5.4  12.6  0.428  2.7
# 96   97               Saddiq Bey  ATL  54  28.5  14.5   4.6  11.5  0.404  1.9
# 97   98              Brook Lopez  MIL  57  30.3  14.5   5.5  10.9  0.507  1.8
# 98   99             Bobby Portis  MIL  47  26.8  14.4   6.0  12.0  0.499  1.2
# 99  100        Jonas Valanciunas  NOP  58  24.7  14.4   5.7  10.5  0.544  0.5
#
# ...

# %%
tables4= pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Post-All-Star_Game')

# %%
tables4[6]
# Out:
#       #                   Player Team  GP   MPG   PPG   FGM   FGA    FG%  3PM  \
# 0     1           Damian Lillard  POR  12  36.8  35.1  10.1  22.6  0.446  4.4
# 1     2  Shai Gilgeous-Alexander  OKC  15  35.9  33.3  10.9  21.1  0.516  0.7
# 2     3              Joel Embiid  PHI  21  34.0  33.0  11.0  19.2  0.574  0.8
# 3     4         Donovan Mitchell  CLE  18  36.4  30.9  11.3  22.9  0.495  3.5
# 4     5             Devin Booker  PHX  20  35.9  29.7  10.6  20.3  0.523  1.9
# ..  ...                      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 95   96              K.J. Martin  HOU  24  31.9  15.3   6.0  10.2  0.588  0.7
# 96   97              Mike Conley  MIN  21  31.5  15.0   4.8  10.2  0.472  2.6
# 97   98       Bennedict Mathurin  IND  18  29.4  14.9   4.8  10.4  0.457  0.9
# 98   99             Cole Anthony  ORL  21  27.4  14.9   5.4  11.4  0.471  1.6
# 99  100      Wendell Carter, Jr.  ORL  18  28.7  14.8   5.6  10.9  0.510  1.6
#
# ...

# %%
df = tables4[6].assign(total_ppg_apg_rpg=tables4[6]['PPG'] + tables4[6]['APG'] + tables4[6]['RPG'])
total_stats = df.groupby(['Player'])['total_ppg_apg_rpg'].sum().reset_index()

# %%
import pandas as pd

# read the HTML table
tables4 = pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Post-All-Star_Game')

# get the sixth table and assign column names
df = tables4[6]
df.columns = df.iloc[0]
df = df[1:]

# save the DataFrame to a CSV file
df.to_csv('player_stats_post.csv', index=False)

# %%
import pandas as pd

# read the HTML table
tables3 = pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Pre-All-Star_Game')

# get the sixth table and assign column names
df = tables4[6]
df.columns = df.iloc[0]
df = df[1:]

# save the DataFrame to a CSV file
df.to_csv('player_stats_post.csv', index=False)

# %%
import pandas as pd

# read the HTML table
tables3 = pd.read_html('https://basketball.realgm.com/nba/stats/2023/Averages/Qualified/points/All/desc/1/Pre-All-Star_Game')

# get the sixth table and assign column names
df = tables3[6]
df.columns = df.iloc[0]
df = df[1:]

# save the DataFrame to a CSV file
df.to_csv('player_stats_pre.csv', index=False)

# %%
tables5[6]
# Out:
# 0     1              Joel Embiid  PHI  66  34.6  33.1  11.0  20.1  0.548  1.0  \
# 0     1              Joel Embiid  PHI  66  34.6  33.1  11.0  20.1  0.548  1.0
# 1     2              Luka Doncic  DAL  66  36.2  32.4  10.9  22.0  0.496  2.8
# 2     3           Damian Lillard  POR  58  36.3  32.2   9.6  20.7  0.463  4.2
# 3     4  Shai Gilgeous-Alexander  OKC  68  35.5  31.4  10.4  20.3  0.510  0.9
# 4     5    Giannis Antetokounmpo  MIL  63  32.1  31.1  11.2  20.3  0.553  0.7
# ..  ...                      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 95   96             Cole Anthony  ORL  60  25.9  13.0   4.6  10.2  0.454  1.3
# 96   97            Austin Reaves  LAL  64  28.8  13.0   4.0   7.7  0.529  1.3
# 97   98                Tre Jones  SAS  68  29.2  12.9   5.0  10.9  0.459  0.7
# 98   99        Jabari Smith, Jr.  HOU  79  31.0  12.8   4.6  11.3  0.408  1.5
# 99  100              K.J. Martin  HOU  82  28.0  12.7   5.0   8.8  0.569  0.8
#
# ...

# %%
AS_df= df[

# %%
df = ('data/player_stats_season.csv')

# %%
df
# Out:
# 'data/player_stats_season.csv'

# %%
df = pd.read_csv('data/player_stats_season.csv')

# %%
df
# Out:
#       1              Joel Embiid  PHI  66  34.6  33.1  11.0  20.1  0.548  1.0  \
# 0     2              Luka Doncic  DAL  66  36.2  32.4  10.9  22.0  0.496  2.8
# 1     3           Damian Lillard  POR  58  36.3  32.2   9.6  20.7  0.463  4.2
# 2     4  Shai Gilgeous-Alexander  OKC  68  35.5  31.4  10.4  20.3  0.510  0.9
# 3     5    Giannis Antetokounmpo  MIL  63  32.1  31.1  11.2  20.3  0.553  0.7
# 4     6             Jayson Tatum  BOS  74  36.9  30.1   9.8  21.1  0.466  3.2
# ..  ...                      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 94   96             Cole Anthony  ORL  60  25.9  13.0   4.6  10.2  0.454  1.3
# 95   97            Austin Reaves  LAL  64  28.8  13.0   4.0   7.7  0.529  1.3
# 96   98                Tre Jones  SAS  68  29.2  12.9   5.0  10.9  0.459  0.7
# 97   99        Jabari Smith, Jr.  HOU  79  31.0  12.8   4.6  11.3  0.408  1.5
# 98  100              K.J. Martin  HOU  82  28.0  12.7   5.0   8.8  0.569  0.8
#
# ...

# %%
AS_df = df['Joel Embiid']

# %%
AS_df['AS'] = 'N'

# %%
AS_df.to_csv('data/AS.csv')
