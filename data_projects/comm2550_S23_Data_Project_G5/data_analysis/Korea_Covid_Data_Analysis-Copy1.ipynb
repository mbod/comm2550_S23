# %%
import pandas as pd

# %%
korea_df = pd.read_csv('../data/Korea_Covid.csv')

# %%
korea_df.shape
# Out:
# (1190, 8)

# %%
korea_df.head(10)
# Out:
#   Date_reported Country_code            Country WHO_region  New_cases  \
# 0        1/3/20           KR  Republic of Korea       WPRO          0
# 1        1/4/20           KR  Republic of Korea       WPRO          0
# 2        1/5/20           KR  Republic of Korea       WPRO          0
# 3        1/6/20           KR  Republic of Korea       WPRO          0
# 4        1/7/20           KR  Republic of Korea       WPRO          0
# 5        1/8/20           KR  Republic of Korea       WPRO          0
# 6        1/9/20           KR  Republic of Korea       WPRO          0
# 7       1/10/20           KR  Republic of Korea       WPRO          0
# 8       1/11/20           KR  Republic of Korea       WPRO          0
# 9       1/12/20           KR  Republic of Korea       WPRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# ...

# %%
korea_df.tail(10)
# Out:
#      Date_reported Country_code            Country WHO_region  New_cases  \
# 1180       3/28/23           KR  Republic of Korea       WPRO      13134
# 1181       3/29/23           KR  Republic of Korea       WPRO      11039
# 1182       3/30/23           KR  Republic of Korea       WPRO      10368
# 1183       3/31/23           KR  Republic of Korea       WPRO          0
# 1184        4/1/23           KR  Republic of Korea       WPRO      10523
# 1185        4/2/23           KR  Republic of Korea       WPRO       9724
# 1186        4/3/23           KR  Republic of Korea       WPRO       4349
# 1187        4/4/23           KR  Republic of Korea       WPRO          0
# 1188        4/5/23           KR  Republic of Korea       WPRO          0
# 1189        4/6/23           KR  Republic of Korea       WPRO          0
#
#       Cumulative_cases  New_deaths  Cumulative_deaths
# 1180          30798723          14              34245
# 1181          30809762           0              34245
# ...

# %%
korea_df.sample(20)
# Out:
#      Date_reported Country_code            Country WHO_region  New_cases  \
# 607         9/1/21           KR  Republic of Korea       WPRO       2020
# 1116       1/23/23           KR  Republic of Korea       WPRO      12262
# 586        8/11/21           KR  Republic of Korea       WPRO       2222
# 361       12/29/20           KR  Republic of Korea       WPRO       1044
# 28         1/31/20           KR  Republic of Korea       WPRO          4
# 65          3/8/20           KR  Republic of Korea       WPRO        367
# 1049      11/17/22           KR  Republic of Korea       WPRO      49418
# 147        5/29/20           KR  Republic of Korea       WPRO         58
# 1127        2/3/23           KR  Republic of Korea       WPRO      14504
# 913         7/4/22           KR  Republic of Korea       WPRO       6239
# 282       10/11/20           KR  Republic of Korea       WPRO         58
# 1091      12/29/22           KR  Republic of Korea       WPRO      65207
# ...

# %%
#identify the columns
korea_df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
try:
    korea_df.set_index('Date_reported', inplace=True)
except:
    pass

# %%
#make a line graph for the number of new cases per day from 1/3/20 to 4/6/23 in South Korea

korea_df['New_cases'].plot(kind='line')

plt.title('New Cases Over Time in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
#make a line graph for the number of new deaths per day from 1/3/20 to 4/6/23 in South Korea
korea_df = pd.read_csv('../data/Korea_Covid.csv')

korea_df.set_index('Date_reported', inplace=True)
korea_df['New_deaths'].plot(kind='line')

plt.title('New Deaths Over Time in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Deaths')

plt.show()

# %%
#make a line graph for the number of cumulative cases per day from 1/3/20 to 4/6/23 in South Korea
korea_df = pd.read_csv('../data/Korea_Covid.csv')

korea_df.set_index('Date_reported', inplace=True)
korea_df['Cumulative_cases'].plot(kind='line')

plt.title('Cumulative Cases Over Time in South Korea')
plt.xlabel('Dates')
plt.ylabel('Cumulative Cases')

plt.show()

# %%
#make a line graph for the number of cumulative deaths per day from 1/3/20 to 4/6/23 in South Korea

korea_df['Cumulative_deaths'].plot(kind='line')

plt.title('Cumulative Deaths Over Time in South Korea')
plt.xlabel('Dates')
plt.ylabel('Cumulative Deaths')

plt.show()

# %%
#total number of cases and deaths in korea
korea_df.tail(1)
# Out:
#               Country_code            Country WHO_region  New_cases  \
# Date_reported
# 4/6/23                  KR  Republic of Korea       WPRO          0
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 4/6/23                 30844726           0              34281

# %%
#describe the data, identifying factors such as mean
korea_df.describe()
# Out:
#            New_cases  Cumulative_cases   New_deaths  Cumulative_deaths
# count    1190.000000      1.190000e+03  1190.000000        1190.000000
# mean    25919.937815      7.818720e+06    28.807563       10210.609244
# std     62538.710407      1.135498e+07    58.465296       12552.546745
# min         0.000000      0.000000e+00     0.000000           0.000000
# 25%       249.250000      2.597700e+04     2.000000         457.750000
# 50%      1537.500000      2.318330e+05     8.000000        2194.000000
# 75%     19375.000000      1.822832e+07    31.000000       24383.750000
# max    621328.000000      3.084473e+07   470.000000       34281.000000

# %% [markdown]
# In this next section, we will be looking for the new case and death data 7 days before implementation of a new Level of social distancing, and track the number of cases in the 30 days following the date of implementation (explaining the 37 in the head). Then, we will graph the progression of cases over this span of 37 days in order to visualize the increase or decrease in cases.

# %%
start_date = '2/22/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date1 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date1)
# Out:
#                New_cases  New_deaths
# Date_reported
# 2/22/20              190           2
# 2/23/20              210           0
# 2/24/20              207           4
# 2/25/20              130           1
# 2/26/20              253           3
# 2/27/20              449           1
# 2/28/20              427           1
# 2/29/20              909           3
# 3/1/20               595           1
# 3/2/20               686           6
# 3/3/20               600           5
# 3/4/20               516           4
# 3/5/20               438           3
# 3/6/20               518           7
# 3/7/20               483           2
# 3/8/20               367           6
# 3/9/20               248           1
# 3/10/20              131           3
# 3/11/20              242           6
# 3/12/20              114           6
# 3/13/20              110           1
# 3/14/20              107           5
# 3/15/20               76           3
# 3/16/20               74           0
# ...

# %%
rows_after_date1['New_cases'].plot(kind='line')

plt.title('New Cases During February 29, 2020 Level 4 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '4/30/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date2 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date2)
# Out:
#                New_cases  New_deaths
# Date_reported
# 4/30/20                4           1
# 5/1/20                 9           1
# 5/2/20                 6           2
# 5/3/20                13           0
# 5/4/20                 8           2
# 5/5/20                 3           2
# 5/6/20                 2           1
# 5/7/20                 4           1
# 5/8/20                12           0
# 5/9/20                18           0
# 5/10/20               34           0
# 5/11/20               35           0
# 5/12/20               27           2
# 5/13/20               26           1
# 5/14/20               29           1
# 5/15/20               27           0
# 5/16/20               19           2
# 5/17/20               13           0
# 5/18/20               15           1
# 5/19/20               13           0
# 5/20/20               32           0
# 5/21/20               12           1
# 5/22/20               20           0
# 5/23/20               23           2
# ...

# %%
rows_after_date2['New_cases'].plot(kind='line')

plt.title('New Cases During May 6, 2020 Decrease in Social Distancing in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '8/9/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date3 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date3)
# Out:
#                New_cases  New_deaths
# Date_reported
# 8/9/20                36           1
# 8/10/20               28           0
# 8/11/20               34           0
# 8/12/20               54           0
# 8/13/20               56           0
# 8/14/20              103           0
# 8/15/20              166           0
# 8/16/20              279           0
# 8/17/20              197           0
# 8/18/20              246           1
# 8/19/20              297           0
# 8/20/20              288           1
# 8/21/20              324           2
# 8/22/20              332           0
# 8/23/20              397           0
# 8/24/20              266           0
# 8/25/20              280           1
# 8/26/20              320           2
# 8/27/20              441           1
# 8/28/20              371           3
# 8/29/20              323           5
# 8/30/20              299           2
# 8/31/20              248           1
# 9/1/20               235           0
# ...

# %%
rows_after_date3['New_cases'].plot(kind='line')

plt.title('New Cases During August 16, 2020 Level 2 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '10/5/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date4 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date4)
# Out:
#                New_cases  New_deaths
# Date_reported
# 10/5/20               73           1
# 10/6/20               75           0
# 10/7/20              114           3
# 10/8/20               69           2
# 10/9/20               54           1
# 10/10/20              72           2
# 10/11/20              58           2
# 10/12/20              97           1
# 10/13/20             102           1
# 10/14/20              73           4
# 10/15/20             110           1
# 10/16/20              47           2
# 10/17/20              73           2
# 10/18/20              91           1
# 10/19/20              76           0
# 10/20/20              58           3
# 10/21/20              89           3
# 10/22/20             121           3
# 10/23/20             155           2
# 10/24/20              77           2
# 10/25/20              61           0
# 10/26/20             119           0
# 10/27/20              88           3
# 10/28/20             103           1
# ...

# %%
rows_after_date4['New_cases'].plot(kind='line')

plt.title('New Cases During October 12, 2020 Level 1 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '11/12/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date5 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date5)
# Out:
#                New_cases  New_deaths
# Date_reported
# 11/12/20             143           0
# 11/13/20             191           1
# 11/14/20             205           4
# 11/15/20             208           1
# 11/16/20             222           1
# 11/17/20             230           0
# 11/18/20             285           2
# 11/19/20             325           2
# 11/20/20             348           3
# 11/21/20             386           2
# 11/22/20             330           2
# 11/23/20             271           4
# 11/24/20             349           1
# 11/25/20             382           3
# 11/26/20             581           2
# 11/27/20             555           1
# 11/28/20             503           6
# 11/29/20             450           1
# 11/30/20             438           3
# 12/1/20              451           0
# 12/2/20              511           0
# 12/3/20              540           3
# 12/4/20              628           7
# 12/5/20              577           4
# ...

# %%
rows_after_date5['New_cases'].plot(kind='line')

plt.title('New Cases During November 19, 2020 Level 1.5 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '11/17/20'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date6 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date6)
# Out:
#                New_cases  New_deaths
# Date_reported
# 11/17/20             230           0
# 11/18/20             285           2
# 11/19/20             325           2
# 11/20/20             348           3
# 11/21/20             386           2
# 11/22/20             330           2
# 11/23/20             271           4
# 11/24/20             349           1
# 11/25/20             382           3
# 11/26/20             581           2
# 11/27/20             555           1
# 11/28/20             503           6
# 11/29/20             450           1
# 11/30/20             438           3
# 12/1/20              451           0
# 12/2/20              511           0
# 12/3/20              540           3
# 12/4/20              628           7
# 12/5/20              577           4
# 12/6/20              631           5
# 12/7/20              615           4
# 12/8/20              587           3
# 12/9/20              670           4
# 12/10/20             680           8
# ...

# %%
rows_after_date6['New_cases'].plot(kind='line')

plt.title('New Cases During November 24, 2020 Level 2, 2.5 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '2/8/21'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date7 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date7)
# Out:
#                New_cases  New_deaths
# Date_reported
# 2/8/21               288           3
# 2/9/21               303           8
# 2/10/21              444           4
# 2/11/21              504          10
# 2/12/21              403          11
# 2/13/21              362           7
# 2/14/21              326           8
# 2/15/21              343           5
# 2/16/21              457           7
# 2/17/21              621           4
# 2/18/21              621           6
# 2/19/21              561           6
# 2/20/21              448           3
# 2/21/21              416           4
# 2/22/21              332           5
# 2/23/21              357          11
# 2/24/21              439           3
# 2/25/21              395           5
# 2/26/21              387           4
# 2/27/21              415          10
# 2/28/21              355           8
# 3/1/21               355           2
# 3/2/21               344           1
# 3/3/21               444           6
# ...

# %%
rows_after_date7['New_cases'].plot(kind='line')

plt.title('New Cases During February 15, 2021 Level 2 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()

# %%
start_date = '7/5/21'
columns_to_select = ['New_cases', 'New_deaths']
rows_after_date8 = korea_df.loc[start_date:, columns_to_select].head(37)

print(rows_after_date8)
# Out:
#                New_cases  New_deaths
# Date_reported
# 7/5/21               711           2
# 7/6/21               746           4
# 7/7/21              1212           1
# 7/8/21              1275           1
# 7/9/21              1316           2
# 7/10/21             1378           2
# 7/11/21             1324           5
# 7/12/21             1100           1
# 7/13/21             1150           2
# 7/14/21             1615           2
# 7/15/21             1599           2
# 7/16/21             1536           1
# 7/17/21             1454           4
# 7/18/21             1451           2
# 7/19/21             1252           1
# 7/20/21             1278           1
# 7/21/21             1780           1
# 7/22/21             1842           3
# 7/23/21             1630           3
# 7/24/21             1629           2
# 7/25/21             1486           5
# 7/26/21             1318           4
# 7/27/21             1365           2
# 7/28/21             1894           4
# ...

# %%
rows_after_date8['New_cases'].plot(kind='line')

plt.title('New Cases During July 12, 2021 Level 4 Implementation in South Korea')
plt.xlabel('Dates')
plt.ylabel('New Cases')

plt.show()
